# %%
#import dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from citipy import citipy
import requests
from datetime import datetime 
from config import weather_api_key

# %%
#create a new set of random latitudes and longitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
coordinates = zip(lats,lngs)
coordinates

# %%
#add the coordinates to a list
coordinates = list(coordinates)

# %%
#get the nearest city using the citipy module
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)

len(cities)
# Out:
# 765

# %%
#perform an API call with the OpenWeatherMap
city_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
#retrieve information from the API call.

#create an empty list to hold the weather data
city_data = []
#print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")
#create counters.
record_count = 1
set_count = 1

#loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city.
    url = city_url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_wdesc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_wdesc})
        
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kaitangata
# Processing Record 2 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | yumbel
# Processing Record 5 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | celestun
# Processing Record 9 of Set 1 | norman wells
# Processing Record 10 of Set 1 | chumikan
# Processing Record 11 of Set 1 | avarua
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | copiapo
# Processing Record 14 of Set 1 | tuktoyaktuk
# Processing Record 15 of Set 1 | rocha
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | castro
# Processing Record 19 of Set 1 | kahului
# Processing Record 20 of Set 1 | hereford
# Processing Record 21 of Set 1 | rikitea
# Processing Record 22 of Set 1 | brae
# Processing Record 23 of Set 1 | glendive
# Processing Record 24 of Set 1 | bluff
# Processing Record 25 of Set 1 | talnakh
# Processing Record 26 of Set 1 | saint-philippe
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | sechura
# Processing Record 30 of Set 1 | addi ugri
# City not found. Skipping...
# Processing Record 31 of Set 1 | liverpool
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | ugoofaaru
# Processing Record 34 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 1 | inongo
# Processing Record 36 of Set 1 | san patricio
# Processing Record 37 of Set 1 | bathsheba
# Processing Record 38 of Set 1 | bengkulu
# Processing Record 39 of Set 1 | deputatskiy
# Processing Record 40 of Set 1 | punta arenas
# Processing Record 41 of Set 1 | east london
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | puerto ayora
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | sidi ali
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | leningradskiy
# Processing Record 49 of Set 1 | zhigalovo
# Processing Record 50 of Set 1 | praia
# Processing Record 1 of Set 2 | tahta
# Processing Record 2 of Set 2 | nikolskoye
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | cabo san lucas
# Processing Record 5 of Set 2 | tasiilaq
# Processing Record 6 of Set 2 | chokurdakh
# Processing Record 7 of Set 2 | cap malheureux
# Processing Record 8 of Set 2 | clyde river
# Processing Record 9 of Set 2 | nocupetaro
# Processing Record 10 of Set 2 | fartura
# Processing Record 11 of Set 2 | alpena
# Processing Record 12 of Set 2 | kapaa
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | hermanus
# Processing Record 15 of Set 2 | jamestown
# Processing Record 16 of Set 2 | arlit
# Processing Record 17 of Set 2 | ostrovnoy
# Processing Record 18 of Set 2 | eraniel
# Processing Record 19 of Set 2 | mount isa
# Processing Record 20 of Set 2 | maceio
# Processing Record 21 of Set 2 | avera
# Processing Record 22 of Set 2 | makinsk
# Processing Record 23 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 24 of Set 2 | pontianak
# Processing Record 25 of Set 2 | buraydah
# Processing Record 26 of Set 2 | vaini
# Processing Record 27 of Set 2 | kon tum
# Processing Record 28 of Set 2 | arraial do cabo
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | cayenne
# Processing Record 31 of Set 2 | saint george
# Processing Record 32 of Set 2 | ilhabela
# Processing Record 33 of Set 2 | padang
# Processing Record 34 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 35 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 2 | cidreira
# Processing Record 37 of Set 2 | thompson
# Processing Record 38 of Set 2 | atuona
# Processing Record 39 of Set 2 | port alfred
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | souillac
# Processing Record 42 of Set 2 | torbay
# Processing Record 43 of Set 2 | fairbanks
# Processing Record 44 of Set 2 | xudat
# Processing Record 45 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 2 | dumai
# Processing Record 47 of Set 2 | hithadhoo
# Processing Record 48 of Set 2 | upernavik
# Processing Record 49 of Set 2 | marzuq
# Processing Record 50 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 3 | virginia beach
# Processing Record 2 of Set 3 | exu
# Processing Record 3 of Set 3 | presidencia roque saenz pena
# Processing Record 4 of Set 3 | kiunga
# Processing Record 5 of Set 3 | viedma
# Processing Record 6 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 3 | kirovskiy
# Processing Record 8 of Set 3 | awbari
# Processing Record 9 of Set 3 | port lincoln
# Processing Record 10 of Set 3 | arman
# Processing Record 11 of Set 3 | mahon
# Processing Record 12 of Set 3 | najran
# Processing Record 13 of Set 3 | churapcha
# Processing Record 14 of Set 3 | imbituba
# Processing Record 15 of Set 3 | butaritari
# Processing Record 16 of Set 3 | bell ville
# Processing Record 17 of Set 3 | san jose
# Processing Record 18 of Set 3 | flinders
# Processing Record 19 of Set 3 | taoudenni
# Processing Record 20 of Set 3 | anadyr
# Processing Record 21 of Set 3 | nemuro
# Processing Record 22 of Set 3 | yaan
# Processing Record 23 of Set 3 | mahebourg
# Processing Record 24 of Set 3 | cazaje
# City not found. Skipping...
# Processing Record 25 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 3 | kruisfontein
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | makakilo city
# Processing Record 29 of Set 3 | jiexiu
# Processing Record 30 of Set 3 | saint-pierre
# Processing Record 31 of Set 3 | filingue
# Processing Record 32 of Set 3 | ewo
# Processing Record 33 of Set 3 | provideniya
# Processing Record 34 of Set 3 | geraldton
# Processing Record 35 of Set 3 | vila velha
# Processing Record 36 of Set 3 | waingapu
# Processing Record 37 of Set 3 | bambous virieux
# Processing Record 38 of Set 3 | tiksi
# Processing Record 39 of Set 3 | dzhebariki-khaya
# Processing Record 40 of Set 3 | padilla
# Processing Record 41 of Set 3 | tura
# Processing Record 42 of Set 3 | carnarvon
# Processing Record 43 of Set 3 | urumqi
# Processing Record 44 of Set 3 | gimbi
# Processing Record 45 of Set 3 | abiy adi
# City not found. Skipping...
# Processing Record 46 of Set 3 | isangel
# Processing Record 47 of Set 3 | north platte
# Processing Record 48 of Set 3 | beitbridge
# Processing Record 49 of Set 3 | monte patria
# Processing Record 50 of Set 3 | ust-kuyga
# Processing Record 1 of Set 4 | rawson
# Processing Record 2 of Set 4 | aykhal
# Processing Record 3 of Set 4 | qaanaaq
# Processing Record 4 of Set 4 | beira
# Processing Record 5 of Set 4 | egvekinot
# Processing Record 6 of Set 4 | xichang
# Processing Record 7 of Set 4 | barrow
# Processing Record 8 of Set 4 | camargo
# Processing Record 9 of Set 4 | sorong
# Processing Record 10 of Set 4 | livingstone
# Processing Record 11 of Set 4 | codrington
# Processing Record 12 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 13 of Set 4 | dukat
# Processing Record 14 of Set 4 | henties bay
# Processing Record 15 of Set 4 | evensk
# Processing Record 16 of Set 4 | constitucion
# Processing Record 17 of Set 4 | ferme-neuve
# Processing Record 18 of Set 4 | klaksvik
# Processing Record 19 of Set 4 | tarakan
# Processing Record 20 of Set 4 | banjar
# Processing Record 21 of Set 4 | lata
# Processing Record 22 of Set 4 | grand gaube
# Processing Record 23 of Set 4 | lagunas
# Processing Record 24 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 26 of Set 4 | pevek
# Processing Record 27 of Set 4 | monrovia
# Processing Record 28 of Set 4 | moundsville
# Processing Record 29 of Set 4 | bo
# City not found. Skipping...
# Processing Record 30 of Set 4 | paita
# Processing Record 31 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 32 of Set 4 | portland
# Processing Record 33 of Set 4 | aldergrove
# Processing Record 34 of Set 4 | lagoa
# Processing Record 35 of Set 4 | san cristobal
# Processing Record 36 of Set 4 | lavrentiya
# Processing Record 37 of Set 4 | kholtoson
# Processing Record 38 of Set 4 | magistralnyy
# Processing Record 39 of Set 4 | paz de ariporo
# City not found. Skipping...
# Processing Record 40 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 4 | mar del plata
# Processing Record 42 of Set 4 | maneadero
# Processing Record 43 of Set 4 | nishihara
# Processing Record 44 of Set 4 | punta cardon
# Processing Record 45 of Set 4 | esperance
# Processing Record 46 of Set 4 | sitka
# Processing Record 47 of Set 4 | mareeba
# Processing Record 48 of Set 4 | araouane
# Processing Record 49 of Set 4 | wattegama
# Processing Record 50 of Set 4 | mount gambier
# Processing Record 1 of Set 5 | talara
# Processing Record 2 of Set 5 | greencastle
# Processing Record 3 of Set 5 | keuruu
# Processing Record 4 of Set 5 | bonthe
# Processing Record 5 of Set 5 | coahuayana
# Processing Record 6 of Set 5 | ibiruba
# Processing Record 7 of Set 5 | santa cruz del sur
# Processing Record 8 of Set 5 | ketchikan
# Processing Record 9 of Set 5 | aklavik
# Processing Record 10 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 5 | trat
# Processing Record 12 of Set 5 | kawalu
# Processing Record 13 of Set 5 | kushima
# Processing Record 14 of Set 5 | severo-yeniseyskiy
# Processing Record 15 of Set 5 | litovko
# Processing Record 16 of Set 5 | narsaq
# Processing Record 17 of Set 5 | lisakovsk
# Processing Record 18 of Set 5 | coolum beach
# Processing Record 19 of Set 5 | brownwood
# Processing Record 20 of Set 5 | camacupa
# Processing Record 21 of Set 5 | laguna
# Processing Record 22 of Set 5 | anjozorobe
# Processing Record 23 of Set 5 | robinson
# Processing Record 24 of Set 5 | neiafu
# Processing Record 25 of Set 5 | qaqortoq
# Processing Record 26 of Set 5 | ardakan
# Processing Record 27 of Set 5 | northam
# Processing Record 28 of Set 5 | pepel
# Processing Record 29 of Set 5 | san pedro
# Processing Record 30 of Set 5 | atkinson
# Processing Record 31 of Set 5 | jinchang
# Processing Record 32 of Set 5 | lardos
# Processing Record 33 of Set 5 | slave lake
# Processing Record 34 of Set 5 | ancud
# Processing Record 35 of Set 5 | cabra
# Processing Record 36 of Set 5 | ryabovo
# Processing Record 37 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 38 of Set 5 | basoko
# Processing Record 39 of Set 5 | kukuna
# Processing Record 40 of Set 5 | krasnoselkup
# Processing Record 41 of Set 5 | pouebo
# Processing Record 42 of Set 5 | jati
# Processing Record 43 of Set 5 | naze
# Processing Record 44 of Set 5 | fujieda
# Processing Record 45 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 5 | gazojak
# Processing Record 47 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 48 of Set 5 | gizo
# Processing Record 49 of Set 5 | tuatapere
# Processing Record 50 of Set 5 | port elizabeth
# Processing Record 1 of Set 6 | mennecy
# Processing Record 2 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 6 | sug-aksy
# City not found. Skipping...
# Processing Record 4 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 5 of Set 6 | moussoro
# Processing Record 6 of Set 6 | felidhoo
# City not found. Skipping...
# Processing Record 7 of Set 6 | abu samrah
# Processing Record 8 of Set 6 | kirensk
# Processing Record 9 of Set 6 | vigrestad
# Processing Record 10 of Set 6 | pisco
# Processing Record 11 of Set 6 | sutton
# Processing Record 12 of Set 6 | cherskiy
# Processing Record 13 of Set 6 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 6 | tuzha
# Processing Record 15 of Set 6 | lufilufi
# Processing Record 16 of Set 6 | caibarien
# Processing Record 17 of Set 6 | hervey bay
# Processing Record 18 of Set 6 | matagami
# Processing Record 19 of Set 6 | fare
# Processing Record 20 of Set 6 | bud
# Processing Record 21 of Set 6 | omsukchan
# Processing Record 22 of Set 6 | saskylakh
# Processing Record 23 of Set 6 | nova olinda do norte
# Processing Record 24 of Set 6 | havre-saint-pierre
# Processing Record 25 of Set 6 | ribas do rio pardo
# Processing Record 26 of Set 6 | camacha
# Processing Record 27 of Set 6 | nelson bay
# Processing Record 28 of Set 6 | ningan
# City not found. Skipping...
# Processing Record 29 of Set 6 | gladstone
# Processing Record 30 of Set 6 | ucluelet
# Processing Record 31 of Set 6 | nshamba
# Processing Record 32 of Set 6 | lebu
# Processing Record 33 of Set 6 | goundam
# Processing Record 34 of Set 6 | coihaique
# Processing Record 35 of Set 6 | micheweni
# Processing Record 36 of Set 6 | saldanha
# Processing Record 37 of Set 6 | cockburn town
# Processing Record 38 of Set 6 | ibia
# Processing Record 39 of Set 6 | storm lake
# Processing Record 40 of Set 6 | port blair
# Processing Record 41 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 42 of Set 6 | saint-paul
# Processing Record 43 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 44 of Set 6 | kasongo
# Processing Record 45 of Set 6 | san jeronimo
# Processing Record 46 of Set 6 | llangefni
# Processing Record 47 of Set 6 | lujan
# Processing Record 48 of Set 6 | airai
# Processing Record 49 of Set 6 | hamilton
# Processing Record 50 of Set 6 | coquimbo
# Processing Record 1 of Set 7 | kushiro
# Processing Record 2 of Set 7 | qujing
# Processing Record 3 of Set 7 | am timan
# Processing Record 4 of Set 7 | paducah
# Processing Record 5 of Set 7 | igarka
# Processing Record 6 of Set 7 | quatre cocos
# Processing Record 7 of Set 7 | hovd
# Processing Record 8 of Set 7 | baykit
# Processing Record 9 of Set 7 | dicabisagan
# Processing Record 10 of Set 7 | barabai
# Processing Record 11 of Set 7 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 7 | salalah
# Processing Record 13 of Set 7 | zhigansk
# Processing Record 14 of Set 7 | westport
# Processing Record 15 of Set 7 | melenki
# Processing Record 16 of Set 7 | mecca
# Processing Record 17 of Set 7 | iqaluit
# Processing Record 18 of Set 7 | alofi
# Processing Record 19 of Set 7 | richards bay
# Processing Record 20 of Set 7 | rutland
# Processing Record 21 of Set 7 | kuvandyk
# Processing Record 22 of Set 7 | pangnirtung
# Processing Record 23 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 24 of Set 7 | waipawa
# Processing Record 25 of Set 7 | pailon
# Processing Record 26 of Set 7 | alyangula
# Processing Record 27 of Set 7 | saint-augustin
# Processing Record 28 of Set 7 | nikolayevka
# Processing Record 29 of Set 7 | broome
# Processing Record 30 of Set 7 | tautira
# Processing Record 31 of Set 7 | bethel
# Processing Record 32 of Set 7 | capaci
# Processing Record 33 of Set 7 | gweta
# Processing Record 34 of Set 7 | aktash
# Processing Record 35 of Set 7 | ponto novo
# Processing Record 36 of Set 7 | tidore
# City not found. Skipping...
# Processing Record 37 of Set 7 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 7 | akureyri
# Processing Record 39 of Set 7 | socorro
# Processing Record 40 of Set 7 | faya
# Processing Record 41 of Set 7 | namibe
# Processing Record 42 of Set 7 | la crosse
# Processing Record 43 of Set 7 | port-gentil
# Processing Record 44 of Set 7 | rio grande
# Processing Record 45 of Set 7 | albion
# Processing Record 46 of Set 7 | luderitz
# Processing Record 47 of Set 7 | hasaki
# Processing Record 48 of Set 7 | dhemaji
# Processing Record 49 of Set 7 | asau
# Processing Record 50 of Set 7 | singleton
# Processing Record 1 of Set 8 | togul
# Processing Record 2 of Set 8 | khandyga
# Processing Record 3 of Set 8 | itarema
# Processing Record 4 of Set 8 | pandan
# Processing Record 5 of Set 8 | san andres
# Processing Record 6 of Set 8 | wajid
# Processing Record 7 of Set 8 | gamba
# Processing Record 8 of Set 8 | puquio
# Processing Record 9 of Set 8 | jaboatao
# Processing Record 10 of Set 8 | komsomolskiy
# Processing Record 11 of Set 8 | port moresby
# Processing Record 12 of Set 8 | epernay
# Processing Record 13 of Set 8 | san policarpo
# Processing Record 14 of Set 8 | necochea
# Processing Record 15 of Set 8 | salinopolis
# Processing Record 16 of Set 8 | ust-tsilma
# Processing Record 17 of Set 8 | port hedland
# Processing Record 18 of Set 8 | sabang
# Processing Record 19 of Set 8 | kloulklubed
# Processing Record 20 of Set 8 | meadow lake
# Processing Record 21 of Set 8 | honningsvag
# Processing Record 22 of Set 8 | qurayyat
# Processing Record 23 of Set 8 | vastervik
# City not found. Skipping...
# Processing Record 24 of Set 8 | sao filipe
# Processing Record 25 of Set 8 | ruatoria
# City not found. Skipping...
# Processing Record 26 of Set 8 | atikokan
# Processing Record 27 of Set 8 | kerema
# Processing Record 28 of Set 8 | kaeo
# Processing Record 29 of Set 8 | wenling
# Processing Record 30 of Set 8 | kedrovyy
# Processing Record 31 of Set 8 | shaki
# Processing Record 32 of Set 8 | okha
# Processing Record 33 of Set 8 | linchuan
# City not found. Skipping...
# Processing Record 34 of Set 8 | yerbogachen
# Processing Record 35 of Set 8 | kardymovo
# Processing Record 36 of Set 8 | penarth
# Processing Record 37 of Set 8 | la ronge
# Processing Record 38 of Set 8 | zhuhai
# Processing Record 39 of Set 8 | georgetown
# Processing Record 40 of Set 8 | bafq
# Processing Record 41 of Set 8 | leh
# Processing Record 42 of Set 8 | faanui
# Processing Record 43 of Set 8 | fortuna
# Processing Record 44 of Set 8 | victoria
# Processing Record 45 of Set 8 | talcahuano
# Processing Record 46 of Set 8 | sol-iletsk
# Processing Record 47 of Set 8 | bonavista
# Processing Record 48 of Set 8 | lichinga
# Processing Record 49 of Set 8 | gola gokarannath
# Processing Record 50 of Set 8 | narasannapeta
# Processing Record 1 of Set 9 | vardo
# Processing Record 2 of Set 9 | sochi
# Processing Record 3 of Set 9 | nichinan
# Processing Record 4 of Set 9 | raton
# Processing Record 5 of Set 9 | manuk mangkaw
# Processing Record 6 of Set 9 | eyl
# Processing Record 7 of Set 9 | acarau
# Processing Record 8 of Set 9 | karaidel
# Processing Record 9 of Set 9 | maniitsoq
# Processing Record 10 of Set 9 | tocopilla
# Processing Record 11 of Set 9 | ambon
# Processing Record 12 of Set 9 | ulladulla
# Processing Record 13 of Set 9 | krasnoarmeysk
# Processing Record 14 of Set 9 | dingle
# Processing Record 15 of Set 9 | vilhena
# Processing Record 16 of Set 9 | mehamn
# Processing Record 17 of Set 9 | mancio lima
# Processing Record 18 of Set 9 | fochville
# Processing Record 19 of Set 9 | kerteh
# City not found. Skipping...
# Processing Record 20 of Set 9 | ures
# Processing Record 21 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 22 of Set 9 | terrace bay
# Processing Record 23 of Set 9 | vologda
# Processing Record 24 of Set 9 | abu dhabi
# Processing Record 25 of Set 9 | itaguai
# Processing Record 26 of Set 9 | poum
# Processing Record 27 of Set 9 | orlik
# Processing Record 28 of Set 9 | ta khmau
# Processing Record 29 of Set 9 | inhambane
# Processing Record 30 of Set 9 | tongchuan
# Processing Record 31 of Set 9 | longyearbyen
# Processing Record 32 of Set 9 | sterling
# Processing Record 33 of Set 9 | sangar
# Processing Record 34 of Set 9 | pagudpud
# Processing Record 35 of Set 9 | ferrol
# Processing Record 36 of Set 9 | tahoua
# Processing Record 37 of Set 9 | opuwo
# Processing Record 38 of Set 9 | sebring
# Processing Record 39 of Set 9 | sistranda
# Processing Record 40 of Set 9 | takoradi
# Processing Record 41 of Set 9 | te anau
# Processing Record 42 of Set 9 | banda aceh
# Processing Record 43 of Set 9 | baculin
# Processing Record 44 of Set 9 | ambilobe
# Processing Record 45 of Set 9 | margate
# Processing Record 46 of Set 9 | medea
# Processing Record 47 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 48 of Set 9 | aksu
# Processing Record 49 of Set 9 | adwa
# Processing Record 50 of Set 9 | goderich
# Processing Record 1 of Set 10 | thinadhoo
# Processing Record 2 of Set 10 | le mars
# Processing Record 3 of Set 10 | bolobo
# Processing Record 4 of Set 10 | nampula
# Processing Record 5 of Set 10 | jieshi
# Processing Record 6 of Set 10 | plouzane
# Processing Record 7 of Set 10 | santa rosa
# Processing Record 8 of Set 10 | kavieng
# Processing Record 9 of Set 10 | korla
# Processing Record 10 of Set 10 | skjervoy
# Processing Record 11 of Set 10 | high rock
# Processing Record 12 of Set 10 | yar-sale
# Processing Record 13 of Set 10 | fort saint john
# City not found. Skipping...
# Processing Record 14 of Set 10 | varna
# Processing Record 15 of Set 10 | kokkola
# Processing Record 16 of Set 10 | acapulco
# Processing Record 17 of Set 10 | porto torres
# Processing Record 18 of Set 10 | guhagar
# Processing Record 19 of Set 10 | wasilla
# Processing Record 20 of Set 10 | adamas
# Processing Record 21 of Set 10 | severo-kurilsk
# Processing Record 22 of Set 10 | yulara
# Processing Record 23 of Set 10 | port keats
# Processing Record 24 of Set 10 | cumana
# Processing Record 25 of Set 10 | serebryansk
# Processing Record 26 of Set 10 | vila franca do campo
# Processing Record 27 of Set 10 | seoul
# Processing Record 28 of Set 10 | khatanga
# Processing Record 29 of Set 10 | ellisras
# Processing Record 30 of Set 10 | nanortalik
# Processing Record 31 of Set 10 | veraval
# Processing Record 32 of Set 10 | vao
# Processing Record 33 of Set 10 | iisalmi
# Processing Record 34 of Set 10 | caceres
# Processing Record 35 of Set 10 | ekhabi
# Processing Record 36 of Set 10 | sao jose da coroa grande
# Processing Record 37 of Set 10 | barao de melgaco
# Processing Record 38 of Set 10 | verkhoyansk
# Processing Record 39 of Set 10 | kastamonu
# Processing Record 40 of Set 10 | alta floresta
# Processing Record 41 of Set 10 | esfarayen
# Processing Record 42 of Set 10 | port hardy
# Processing Record 43 of Set 10 | syracuse
# Processing Record 44 of Set 10 | oistins
# Processing Record 45 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 46 of Set 10 | fairlie
# Processing Record 47 of Set 10 | mbala
# Processing Record 48 of Set 10 | kristiansund
# Processing Record 49 of Set 10 | moron
# Processing Record 50 of Set 10 | pedasi
# Processing Record 1 of Set 11 | lasa
# Processing Record 2 of Set 11 | ozinki
# Processing Record 3 of Set 11 | bassila
# Processing Record 4 of Set 11 | painesville
# Processing Record 5 of Set 11 | kamenskoye
# City not found. Skipping...
# Processing Record 6 of Set 11 | ust-maya
# Processing Record 7 of Set 11 | etchojoa
# Processing Record 8 of Set 11 | harper
# Processing Record 9 of Set 11 | bilibino
# Processing Record 10 of Set 11 | asbestovskiy
# Processing Record 11 of Set 11 | husavik
# Processing Record 12 of Set 11 | marrakesh
# Processing Record 13 of Set 11 | kargasok
# Processing Record 14 of Set 11 | roald
# Processing Record 15 of Set 11 | marawi
# Processing Record 16 of Set 11 | bocaranga
# City not found. Skipping...
# Processing Record 17 of Set 11 | luebo
# Processing Record 18 of Set 11 | ozgon
# City not found. Skipping...
# Processing Record 19 of Set 11 | saint anthony
# Processing Record 20 of Set 11 | shieli
# Processing Record 21 of Set 11 | mayskiy
# Processing Record 22 of Set 11 | hofn
# Processing Record 23 of Set 11 | nuuk
# Processing Record 24 of Set 11 | huarmey
# Processing Record 25 of Set 11 | neryungri
# Processing Record 26 of Set 11 | srednekolymsk
# Processing Record 27 of Set 11 | khuzhir
# Processing Record 28 of Set 11 | west fargo
# Processing Record 29 of Set 11 | visnes
# Processing Record 30 of Set 11 | spoleto
# Processing Record 31 of Set 11 | teguldet
# Processing Record 32 of Set 11 | garhakota
# Processing Record 33 of Set 11 | tailai
# Processing Record 34 of Set 11 | comodoro rivadavia
# Processing Record 35 of Set 11 | cap-aux-meules
# Processing Record 36 of Set 11 | bogale
# Processing Record 37 of Set 11 | raudeberg
# Processing Record 38 of Set 11 | sydney
# Processing Record 39 of Set 11 | buala
# Processing Record 40 of Set 11 | kolokani
# Processing Record 41 of Set 11 | chikoy
# City not found. Skipping...
# Processing Record 42 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 11 | guerrero negro
# Processing Record 44 of Set 11 | vanimo
# Processing Record 45 of Set 11 | sokolo
# Processing Record 46 of Set 11 | pitsunda
# Processing Record 47 of Set 11 | novoagansk
# Processing Record 48 of Set 11 | acari
# Processing Record 49 of Set 11 | ciudad bolivar
# Processing Record 50 of Set 11 | nanlong
# Processing Record 1 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 2 of Set 12 | paraiso
# Processing Record 3 of Set 12 | southbridge
# Processing Record 4 of Set 12 | hurghada
# Processing Record 5 of Set 12 | dera ghazi khan
# Processing Record 6 of Set 12 | guider
# Processing Record 7 of Set 12 | mindelo
# Processing Record 8 of Set 12 | matir
# City not found. Skipping...
# Processing Record 9 of Set 12 | pangody
# Processing Record 10 of Set 12 | sao gabriel da cachoeira
# Processing Record 11 of Set 12 | san quintin
# Processing Record 12 of Set 12 | nicoya
# Processing Record 13 of Set 12 | mlimba
# Processing Record 14 of Set 12 | tungor
# Processing Record 15 of Set 12 | malinovoye ozero
# Processing Record 16 of Set 12 | burnie
# Processing Record 17 of Set 12 | gondanglegi
# Processing Record 18 of Set 12 | sampit
# Processing Record 19 of Set 12 | turku
# Processing Record 20 of Set 12 | tabuk
# Processing Record 21 of Set 12 | mikhaylovka
# Processing Record 22 of Set 12 | victor harbor
# Processing Record 23 of Set 12 | hagdan
# Processing Record 24 of Set 12 | beringovskiy
# Processing Record 25 of Set 12 | tutoia
# Processing Record 26 of Set 12 | santa cruz cabralia
# Processing Record 27 of Set 12 | hyeres
# Processing Record 28 of Set 12 | capao da canoa
# Processing Record 29 of Set 12 | saint-louis
# Processing Record 30 of Set 12 | los llanos de aridane
# Processing Record 31 of Set 12 | the valley
# Processing Record 32 of Set 12 | maraa
# Processing Record 33 of Set 12 | san buenaventura
# Processing Record 34 of Set 12 | la massana
# Processing Record 35 of Set 12 | pecos
# Processing Record 36 of Set 12 | gourcy
# Processing Record 37 of Set 12 | marihatag
# Processing Record 38 of Set 12 | morris
# Processing Record 39 of Set 12 | daru
# Processing Record 40 of Set 12 | numaligarh
# Processing Record 41 of Set 12 | washougal
# Processing Record 42 of Set 12 | shu
# Processing Record 43 of Set 12 | jumla
# Processing Record 44 of Set 12 | touros
# Processing Record 45 of Set 12 | haapiti
# Processing Record 46 of Set 12 | mezen
# Processing Record 47 of Set 12 | chimbote
# Processing Record 48 of Set 12 | itaituba
# Processing Record 49 of Set 12 | luba
# Processing Record 50 of Set 12 | benguela
# Processing Record 1 of Set 13 | gubkin
# Processing Record 2 of Set 13 | nakamura
# Processing Record 3 of Set 13 | pimentel
# Processing Record 4 of Set 13 | karwar
# Processing Record 5 of Set 13 | hilsa
# Processing Record 6 of Set 13 | sapa
# Processing Record 7 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 8 of Set 13 | skegness
# Processing Record 9 of Set 13 | zyryanka
# Processing Record 10 of Set 13 | lazaro cardenas
# Processing Record 11 of Set 13 | natori
# Processing Record 12 of Set 13 | coos bay
# Processing Record 13 of Set 13 | barcelos
# Processing Record 14 of Set 13 | grindavik
# Processing Record 15 of Set 13 | aquiraz
# Processing Record 16 of Set 13 | ragonvalia
# Processing Record 17 of Set 13 | kosh-agach
# Processing Record 18 of Set 13 | christchurch
# Processing Record 19 of Set 13 | congonhas
# Processing Record 20 of Set 13 | ayan
# Processing Record 21 of Set 13 | berlevag
# Processing Record 22 of Set 13 | la libertad
# Processing Record 23 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 13 | broken hill
# Processing Record 25 of Set 13 | san angelo
# Processing Record 26 of Set 13 | sola
# Processing Record 27 of Set 13 | rockhampton
# Processing Record 28 of Set 13 | kenora
# Processing Record 29 of Set 13 | tarko-sale
# Processing Record 30 of Set 13 | gannan
# Processing Record 31 of Set 13 | yudong
# Processing Record 32 of Set 13 | pak phanang
# Processing Record 33 of Set 13 | prachuap khiri khan
# Processing Record 34 of Set 13 | biak
# Processing Record 35 of Set 13 | mitry-mory
# Processing Record 36 of Set 13 | baruun-urt
# Processing Record 37 of Set 13 | praia da vitoria
# Processing Record 38 of Set 13 | severobaykalsk
# Processing Record 39 of Set 13 | hobyo
# Processing Record 40 of Set 13 | srandakan
# Processing Record 41 of Set 13 | lusambo
# Processing Record 42 of Set 13 | resistencia
# Processing Record 43 of Set 13 | ambanja
# Processing Record 44 of Set 13 | amazar
# Processing Record 45 of Set 13 | aswan
# Processing Record 46 of Set 13 | betioky
# Processing Record 47 of Set 13 | requena
# Processing Record 48 of Set 13 | ilek
# Processing Record 49 of Set 13 | katangli
# Processing Record 50 of Set 13 | moorhead
# Processing Record 1 of Set 14 | alekseyevka
# Processing Record 2 of Set 14 | sovetskiy
# Processing Record 3 of Set 14 | at-bashi
# Processing Record 4 of Set 14 | progreso
# Processing Record 5 of Set 14 | trojan
# Processing Record 6 of Set 14 | nueva gerona
# Processing Record 7 of Set 14 | turmalina
# Processing Record 8 of Set 14 | ler
# Processing Record 9 of Set 14 | galveston
# Processing Record 10 of Set 14 | manakara
# Processing Record 11 of Set 14 | porvoo
# Processing Record 12 of Set 14 | chernyshevskiy
# Processing Record 13 of Set 14 | nouadhibou
# Processing Record 14 of Set 14 | prince rupert
# Processing Record 15 of Set 14 | araioses
# Processing Record 16 of Set 14 | cururupu
# Processing Record 17 of Set 14 | port hueneme
# Processing Record 18 of Set 14 | lorengau
# Processing Record 19 of Set 14 | mysliborz
# Processing Record 20 of Set 14 | santa isabel
# Processing Record 21 of Set 14 | shimsk
# Processing Record 22 of Set 14 | iwanai
# Processing Record 23 of Set 14 | kanye
# Processing Record 24 of Set 14 | dimitrovgrad
# Processing Record 25 of Set 14 | altamira
# Processing Record 26 of Set 14 | lahaina
# Processing Record 27 of Set 14 | poronaysk
# Processing Record 28 of Set 14 | sao joao da barra
# Processing Record 29 of Set 14 | cuencame
# Processing Record 30 of Set 14 | kuandian
# Processing Record 31 of Set 14 | meulaboh
# Processing Record 32 of Set 14 | kavaratti
# Processing Record 33 of Set 14 | rincon de la victoria
# Processing Record 34 of Set 14 | awjilah
# Processing Record 35 of Set 14 | mayo
# Processing Record 36 of Set 14 | timizart
# Processing Record 37 of Set 14 | olinda
# Processing Record 38 of Set 14 | takestan
# Processing Record 39 of Set 14 | buta
# Processing Record 40 of Set 14 | niamey
# Processing Record 41 of Set 14 | izhevskoye
# Processing Record 42 of Set 14 | chiredzi
# Processing Record 43 of Set 14 | sur
# Processing Record 44 of Set 14 | bridgend
# Processing Record 45 of Set 14 | verkhnetulomskiy
# Processing Record 46 of Set 14 | elk
# Processing Record 47 of Set 14 | teya
# Processing Record 48 of Set 14 | sioux lookout
# Processing Record 49 of Set 14 | asosa
# Processing Record 50 of Set 14 | derzhavinsk
# Processing Record 1 of Set 15 | sligo
# Processing Record 2 of Set 15 | tianpeng
# Processing Record 3 of Set 15 | gobabis
# Processing Record 4 of Set 15 | whitianga
# Processing Record 5 of Set 15 | rosetta
# Processing Record 6 of Set 15 | tres arroyos
# Processing Record 7 of Set 15 | ambovombe
# Processing Record 8 of Set 15 | la asuncion
# Processing Record 9 of Set 15 | houston
# Processing Record 10 of Set 15 | ust-nera
# Processing Record 11 of Set 15 | rosarito
# Processing Record 12 of Set 15 | santa clarita
# Processing Record 13 of Set 15 | chakan
# Processing Record 14 of Set 15 | kuching
# Processing Record 15 of Set 15 | massakory
# Processing Record 16 of Set 15 | yelkhovka
# Processing Record 17 of Set 15 | horsham
# Processing Record 18 of Set 15 | roma
# Processing Record 19 of Set 15 | pierre
# Processing Record 20 of Set 15 | dunedin
# Processing Record 21 of Set 15 | karachi
# Processing Record 22 of Set 15 | boende
# Processing Record 23 of Set 15 | kailua
# Processing Record 24 of Set 15 | santo antonio do ica
# Processing Record 25 of Set 15 | honiara
# Processing Record 26 of Set 15 | dwarka
# Processing Record 27 of Set 15 | havre
# Processing Record 28 of Set 15 | pochutla
# Processing Record 29 of Set 15 | senador jose porfirio
# Processing Record 30 of Set 15 | viytivka
# Processing Record 31 of Set 15 | matamoros
# Processing Record 32 of Set 15 | sambava
# Processing Record 33 of Set 15 | vikhorevka
# Processing Record 34 of Set 15 | mankono
# Processing Record 35 of Set 15 | imuris
# Processing Record 36 of Set 15 | labuan
# Processing Record 37 of Set 15 | morondava
# Processing Record 38 of Set 15 | oranjemund
# Processing Record 39 of Set 15 | la palma
# Processing Record 40 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 41 of Set 15 | monster
# Processing Record 42 of Set 15 | havoysund
# Processing Record 43 of Set 15 | mudon
# Processing Record 44 of Set 15 | pocone
# Processing Record 45 of Set 15 | yorkton
# Processing Record 46 of Set 15 | longonjo
# Processing Record 47 of Set 15 | murray bridge
# Processing Record 48 of Set 15 | williston
# Processing Record 49 of Set 15 | ukiah
# Processing Record 50 of Set 15 | weligama
# Processing Record 1 of Set 16 | choix
# Processing Record 2 of Set 16 | hambantota
# Processing Record 3 of Set 16 | panalingaan
# Processing Record 4 of Set 16 | yumen
# Processing Record 5 of Set 16 | exeter
# Processing Record 6 of Set 16 | bocana de paiwas
# Processing Record 7 of Set 16 | mrirt
# City not found. Skipping...
# Processing Record 8 of Set 16 | walvis bay
# Processing Record 9 of Set 16 | gilgit
# Processing Record 10 of Set 16 | kandrian
# Processing Record 11 of Set 16 | tuy hoa
# Processing Record 12 of Set 16 | guiren
# Processing Record 13 of Set 16 | artyom
# Processing Record 14 of Set 16 | haverfordwest
# Processing Record 15 of Set 16 | dolores
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Kaitangata -46.2817  169.8464     49.23        74          73
# 1         Mataura -46.1927  168.8643     47.80        67          12
# 2          Yumbel -37.0833  -72.5667     70.03        29         100
# 3  Ribeira Grande  38.5167  -28.7000     72.00        88          75
# 4        Celestun  20.8667  -90.4000     80.29        51          18
# 5    Norman Wells  65.2820 -126.8329     15.84        92          75
# 6        Chumikan  54.7183  135.3150     17.74        80          12
# 7          Avarua -21.2078 -159.7750     71.65        73         100
# 8         Ushuaia -54.8000  -68.3000     49.66        53           0
# 9         Copiapo -27.3667  -70.3333     62.29        23           0
#
#    Wind Speed      Description
# 0        5.46    broken clouds
# 1        5.73       few clouds
# 2        6.69  overcast clouds
# 3       23.02    broken clouds
# 4       10.51       few clouds
# 5        2.30             mist
# 6        8.10       few clouds
# 7       10.36  overcast clouds
# 8       14.97        clear sky
# 9        8.28        clear sky

# %%
#create the output file (csv)
output_data_file = "WeatherPy_Database.cvs"
#export the city_data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
